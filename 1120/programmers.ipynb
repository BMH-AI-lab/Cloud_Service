# %%
def solution(s):
    count = 0
    count_remove_zero = 0

    while s != '1':
        zeros = s.count('0')
        count_remove_zero += zeros

        s = s.replace('0', '')
        length = len(s)
        s = bin(length)[2:]
        count += 1

    answer = []
    return [count, count_remove_zero]

solution("110010101001")
# Out:
# [3, 8]

# %%
def solution(n):
    answer = 0
    m = 1

    while m * (m - 1) // 2 < n:
        if (n - m * (m - 1) // 2) % m == 0:
            answer += 1
        m += 1

    return answer

solution(15)
# Out:
# 4
